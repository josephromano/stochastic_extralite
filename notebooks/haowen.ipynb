# %%
# %run stochastic_lite.ipynb

# %%
####################
# Inputs
####################

# PSD ~ 1e-42 strain^2 / Hz
# PSD = 2 sigma**2 * deltaT = 2 * sigma**2 / Fs
# = sigma**2 / 512
# sigma = sqrt(1e-42 * 512)

sigma             = np.sqrt(512 * 1e-42) # strain
sigma_inj         = sigma/10.
NSegments         = 50
Fs                = 1024. # Hz
segmentDuration   = 64.0 # s
t0                = 0 # s
TAvg              = 4.0 # s

####################
# Computed quantities
####################

NSamplesPerSegment=int(segmentDuration*Fs) 
deltaT=1/Fs
fNyquist=1/(2*deltaT)
deltaF=1/segmentDuration
deltaFStoch=1/TAvg
NAvgs = 2 * int(segmentDuration / TAvg) - 1
jobDuration = NSegments * segmentDuration

# %%
# Theoretical PSD and sigma for white GWB and white noise

Nfreqs = int((Fs/2) / deltaFStoch)
alpha=3 # white signal
fref=25

w1w2bar, w1w2squaredbar,_,_ = window_factors(NSamplesPerSegment)
PSD_theor = 2*(sigma**2)*deltaT
Pgw_theor = 2*(sigma_inj**2)*deltaT

H_theor = (3*H0**2)/(10*np.pi**2*fref**3) # don't need *(P1.freqs/fref)**(alpha-3) for alpha=3
Y_theor = Pgw_theor/H_theor

var_theor = 1./((segmentDuration)*2*Nfreqs*deltaFStoch * H_theor**2/(PSD_theor**2))
var_theor = w1w2squaredbar / w1w2bar**2 * var_theor
sigma_theor = np.sqrt(var_theor)

print('sigma_theor =', sigma_theor)
print('Y_theor =', Y_theor)
# Out:
# sigma_theor = 0.00019118756492816
# Y_theor = 0.0004894401662160896

# %%
# simulate the time series data
noise1=sigma*np.random.randn(int(NSamplesPerSegment*NSegments))
noise2=sigma*np.random.randn(int(NSamplesPerSegment*NSegments))
inj=sigma_inj*np.random.randn(int(NSamplesPerSegment*NSegments))

times=np.arange(t0,t0+NSegments*segmentDuration,1/Fs)

d1=TimeSeries(times,noise1 + inj)
d2=TimeSeries(times,noise2 + inj)

# %%
# run stochastic pipeline
alpha=3
Ys,sigs,Y_fs,var_fs,segmentStartTimes,freqs=stochastic(d1,d2,segmentDuration,deltaFStoch,
                                                      fref=fref,alpha=alpha)
# Out:
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/1069487270.py:109: RuntimeWarning: divide by zero encountered in divide
#   S0 = FrequencySeries(freqs, (3*H0**2)/(10*np.pi**2*freqs**3))
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/1069487270.py:118: ComplexWarning: Casting complex values to real discards the imaginary part
#   Ys[II],sigs[II] = calc_Y_sigma_from_Yf_varf(Y_f.data[1:],var_f.data[1:], freqs=freqs[1:], alpha=alpha, fref=fref)
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/1069487270.py:120: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y_fs[:,II],var_fs[:,II] = Y_f.data, var_f.data
# stochastic: Done with Interval 1 / 95
# 	Y     = 2.532832e-04
# 	sigma = 1.893090e-04
# 	SNR   = 1.337936
# stochastic: Done with Interval 2 / 95
# 	Y     = 2.287814e-04
# 	sigma = 1.894239e-04
# 	SNR   = 1.207775
# stochastic: Done with Interval 3 / 95
# 	Y     = 5.537269e-05
# 	sigma = 1.896203e-04
# 	SNR   = 0.292019
# stochastic: Done with Interval 4 / 95
# 	Y     = 1.449462e-04
# 	sigma = 1.896685e-04
# 	SNR   = 0.764208
# stochastic: Done with Interval 5 / 95
# 	Y     = 2.446707e-04
# 	sigma = 1.892061e-04
# 	SNR   = 1.293144
# stochastic: Done with Interval 6 / 95
# 	Y     = 7.222343e-05
# 	sigma = 1.891201e-04
# 	SNR   = 0.381892
# stochastic: Done with Interval 7 / 95
# 	Y     = 3.600523e-04
# 	sigma = 1.895322e-04
# 	SNR   = 1.899689
# stochastic: Done with Interval 8 / 95
# 	Y     = 1.046542e-04
# 	sigma = 1.900047e-04
# 	SNR   = 0.550798
# stochastic: Done with Interval 9 / 95
# 	Y     = 3.056009e-04
# 	sigma = 1.897831e-04
# 	SNR   = 1.610264
# stochastic: Done with Interval 10 / 95
# 	Y     = 2.572422e-05
# 	sigma = 1.890501e-04
# 	SNR   = 0.136071
# stochastic: Done with Interval 11 / 95
# 	Y     = 3.009432e-04
# 	sigma = 1.889443e-04
# 	SNR   = 1.592761
# stochastic: Done with Interval 12 / 95
# 	Y     = 1.013144e-04
# 	sigma = 1.892504e-04
# 	SNR   = 0.535346
# stochastic: Done with Interval 13 / 95
# 	Y     = 1.683556e-04
# 	sigma = 1.892857e-04
# 	SNR   = 0.889426
# stochastic: Done with Interval 14 / 95
# 	Y     = 8.796649e-05
# 	sigma = 1.894914e-04
# 	SNR   = 0.464224
# stochastic: Done with Interval 15 / 95
# 	Y     = 1.639863e-04
# 	sigma = 1.889409e-04
# 	SNR   = 0.867924
# stochastic: Done with Interval 16 / 95
# 	Y     = 1.916224e-04
# 	sigma = 1.876440e-04
# 	SNR   = 1.021202
# stochastic: Done with Interval 17 / 95
# 	Y     = 2.066653e-04
# 	sigma = 1.884448e-04
# 	SNR   = 1.096688
# stochastic: Done with Interval 18 / 95
# 	Y     = 2.750236e-04
# 	sigma = 1.899514e-04
# 	SNR   = 1.447863
# stochastic: Done with Interval 19 / 95
# 	Y     = 1.936756e-04
# 	sigma = 1.901204e-04
# 	SNR   = 1.018700
# stochastic: Done with Interval 20 / 95
# 	Y     = 2.060712e-04
# 	sigma = 1.889120e-04
# 	SNR   = 1.090831
# stochastic: Done with Interval 21 / 95
# 	Y     = -1.354506e-05
# 	sigma = 1.892805e-04
# 	SNR   = -0.071561
# stochastic: Done with Interval 22 / 95
# 	Y     = 2.090487e-04
# 	sigma = 1.897241e-04
# 	SNR   = 1.101856
# stochastic: Done with Interval 23 / 95
# 	Y     = 3.691896e-04
# 	sigma = 1.901097e-04
# 	SNR   = 1.941982
# stochastic: Done with Interval 24 / 95
# 	Y     = 3.440800e-04
# 	sigma = 1.897843e-04
# 	SNR   = 1.813006
# stochastic: Done with Interval 25 / 95
# 	Y     = 2.251583e-04
# 	sigma = 1.894767e-04
# 	SNR   = 1.188316
# stochastic: Done with Interval 26 / 95
# 	Y     = 3.866820e-04
# 	sigma = 1.899896e-04
# 	SNR   = 2.035279
# stochastic: Done with Interval 27 / 95
# 	Y     = 1.573904e-04
# 	sigma = 1.897693e-04
# 	SNR   = 0.829378
# stochastic: Done with Interval 28 / 95
# 	Y     = 2.621516e-04
# 	sigma = 1.898333e-04
# 	SNR   = 1.380957
# stochastic: Done with Interval 29 / 95
# 	Y     = 5.732747e-05
# 	sigma = 1.896346e-04
# 	SNR   = 0.302305
# stochastic: Done with Interval 30 / 95
# 	Y     = 1.667210e-04
# 	sigma = 1.899591e-04
# 	SNR   = 0.877668
# stochastic: Done with Interval 31 / 95
# 	Y     = 2.039194e-04
# 	sigma = 1.901849e-04
# 	SNR   = 1.072216
# stochastic: Done with Interval 32 / 95
# 	Y     = 3.211447e-04
# 	sigma = 1.899075e-04
# 	SNR   = 1.691058
# stochastic: Done with Interval 33 / 95
# 	Y     = 3.040428e-04
# 	sigma = 1.895343e-04
# 	SNR   = 1.604157
# stochastic: Done with Interval 34 / 95
# 	Y     = 1.974725e-04
# 	sigma = 1.898625e-04
# 	SNR   = 1.040082
# stochastic: Done with Interval 35 / 95
# 	Y     = 2.812383e-04
# 	sigma = 1.898154e-04
# 	SNR   = 1.481641
# stochastic: Done with Interval 36 / 95
# 	Y     = 1.204812e-04
# 	sigma = 1.893450e-04
# 	SNR   = 0.636305
# stochastic: Done with Interval 37 / 95
# 	Y     = 1.990456e-04
# 	sigma = 1.895382e-04
# 	SNR   = 1.050161
# stochastic: Done with Interval 38 / 95
# 	Y     = 2.730332e-04
# 	sigma = 1.898125e-04
# 	SNR   = 1.438436
# stochastic: Done with Interval 39 / 95
# 	Y     = 2.744165e-04
# 	sigma = 1.896418e-04
# 	SNR   = 1.447025
# stochastic: Done with Interval 40 / 95
# 	Y     = 2.623461e-04
# 	sigma = 1.897916e-04
# 	SNR   = 1.382285
# stochastic: Done with Interval 41 / 95
# 	Y     = 3.378246e-04
# 	sigma = 1.895648e-04
# 	SNR   = 1.782106
# stochastic: Done with Interval 42 / 95
# 	Y     = 1.600887e-04
# 	sigma = 1.890599e-04
# 	SNR   = 0.846762
# stochastic: Done with Interval 43 / 95
# 	Y     = 1.984813e-04
# 	sigma = 1.893542e-04
# 	SNR   = 1.048201
# stochastic: Done with Interval 44 / 95
# 	Y     = 1.338773e-04
# 	sigma = 1.900490e-04
# 	SNR   = 0.704436
# stochastic: Done with Interval 45 / 95
# 	Y     = 3.589514e-04
# 	sigma = 1.892535e-04
# 	SNR   = 1.896670
# stochastic: Done with Interval 46 / 95
# 	Y     = 2.475145e-04
# 	sigma = 1.885841e-04
# 	SNR   = 1.312489
# stochastic: Done with Interval 47 / 95
# 	Y     = 1.563232e-04
# 	sigma = 1.887780e-04
# 	SNR   = 0.828080
# stochastic: Done with Interval 48 / 95
# 	Y     = 3.776114e-04
# 	sigma = 1.893213e-04
# 	SNR   = 1.994553
# stochastic: Done with Interval 49 / 95
# 	Y     = 1.627222e-04
# 	sigma = 1.897921e-04
# 	SNR   = 0.857371
# stochastic: Done with Interval 50 / 95
# 	Y     = 2.229603e-04
# 	sigma = 1.892161e-04
# 	SNR   = 1.178337
# stochastic: Done with Interval 51 / 95
# 	Y     = 2.308156e-04
# 	sigma = 1.886309e-04
# 	SNR   = 1.223636
# stochastic: Done with Interval 52 / 95
# 	Y     = 4.105787e-05
# 	sigma = 1.887226e-04
# 	SNR   = 0.217557
# stochastic: Done with Interval 53 / 95
# 	Y     = 2.081460e-04
# 	sigma = 1.899453e-04
# 	SNR   = 1.095821
# stochastic: Done with Interval 54 / 95
# 	Y     = 3.376647e-04
# 	sigma = 1.899128e-04
# 	SNR   = 1.777998
# stochastic: Done with Interval 55 / 95
# 	Y     = -3.201248e-05
# 	sigma = 1.899761e-04
# 	SNR   = -0.168508
# stochastic: Done with Interval 56 / 95
# 	Y     = 1.420266e-04
# 	sigma = 1.898074e-04
# 	SNR   = 0.748267
# stochastic: Done with Interval 57 / 95
# 	Y     = 3.251475e-04
# 	sigma = 1.897475e-04
# 	SNR   = 1.713580
# stochastic: Done with Interval 58 / 95
# 	Y     = 6.651704e-05
# 	sigma = 1.896283e-04
# 	SNR   = 0.350776
# stochastic: Done with Interval 59 / 95
# 	Y     = 3.085087e-04
# 	sigma = 1.893583e-04
# 	SNR   = 1.629233
# stochastic: Done with Interval 60 / 95
# 	Y     = 4.088746e-04
# 	sigma = 1.900953e-04
# 	SNR   = 2.150892
# stochastic: Done with Interval 61 / 95
# 	Y     = 1.754228e-04
# 	sigma = 1.898400e-04
# 	SNR   = 0.924056
# stochastic: Done with Interval 62 / 95
# 	Y     = 2.679331e-04
# 	sigma = 1.892417e-04
# 	SNR   = 1.415825
# stochastic: Done with Interval 63 / 95
# 	Y     = 2.335687e-04
# 	sigma = 1.892024e-04
# 	SNR   = 1.234491
# stochastic: Done with Interval 64 / 95
# 	Y     = 1.885136e-04
# 	sigma = 1.900895e-04
# 	SNR   = 0.991710
# stochastic: Done with Interval 65 / 95
# 	Y     = 2.614667e-04
# 	sigma = 1.896866e-04
# 	SNR   = 1.378414
# stochastic: Done with Interval 66 / 95
# 	Y     = 2.238872e-04
# 	sigma = 1.889930e-04
# 	SNR   = 1.184632
# stochastic: Done with Interval 67 / 95
# 	Y     = 3.241787e-05
# 	sigma = 1.897149e-04
# 	SNR   = 0.170877
# stochastic: Done with Interval 68 / 95
# 	Y     = 2.326043e-04
# 	sigma = 1.906393e-04
# 	SNR   = 1.220128
# stochastic: Done with Interval 69 / 95
# 	Y     = 1.728690e-04
# 	sigma = 1.901893e-04
# 	SNR   = 0.908932
# stochastic: Done with Interval 70 / 95
# 	Y     = 1.770125e-04
# 	sigma = 1.894865e-04
# 	SNR   = 0.934170
# stochastic: Done with Interval 71 / 95
# 	Y     = 2.100827e-04
# 	sigma = 1.896557e-04
# 	SNR   = 1.107705
# stochastic: Done with Interval 72 / 95
# 	Y     = 7.883159e-05
# 	sigma = 1.898899e-04
# 	SNR   = 0.415144
# stochastic: Done with Interval 73 / 95
# 	Y     = 2.597333e-04
# 	sigma = 1.903835e-04
# 	SNR   = 1.364263
# stochastic: Done with Interval 74 / 95
# 	Y     = 1.699475e-04
# 	sigma = 1.898266e-04
# 	SNR   = 0.895278
# stochastic: Done with Interval 75 / 95
# 	Y     = 1.744006e-04
# 	sigma = 1.897843e-04
# 	SNR   = 0.918941
# stochastic: Done with Interval 76 / 95
# 	Y     = 3.135992e-04
# 	sigma = 1.899121e-04
# 	SNR   = 1.651286
# stochastic: Done with Interval 77 / 95
# 	Y     = 1.889162e-04
# 	sigma = 1.904844e-04
# 	SNR   = 0.991768
# stochastic: Done with Interval 78 / 95
# 	Y     = 1.617913e-04
# 	sigma = 1.898886e-04
# 	SNR   = 0.852033
# stochastic: Done with Interval 79 / 95
# 	Y     = 1.108290e-04
# 	sigma = 1.900281e-04
# 	SNR   = 0.583225
# stochastic: Done with Interval 80 / 95
# 	Y     = 9.499930e-05
# 	sigma = 1.901535e-04
# 	SNR   = 0.499593
# stochastic: Done with Interval 81 / 95
# 	Y     = 3.323322e-04
# 	sigma = 1.905758e-04
# 	SNR   = 1.743833
# stochastic: Done with Interval 82 / 95
# 	Y     = 4.914887e-05
# 	sigma = 1.905432e-04
# 	SNR   = 0.257941
# stochastic: Done with Interval 83 / 95
# 	Y     = 2.566227e-04
# 	sigma = 1.903774e-04
# 	SNR   = 1.347968
# stochastic: Done with Interval 84 / 95
# 	Y     = 1.628014e-04
# 	sigma = 1.896714e-04
# 	SNR   = 0.858334
# stochastic: Done with Interval 85 / 95
# 	Y     = 1.652014e-04
# 	sigma = 1.901896e-04
# 	SNR   = 0.868614
# stochastic: Done with Interval 86 / 95
# 	Y     = 1.240219e-04
# 	sigma = 1.911126e-04
# 	SNR   = 0.648947
# stochastic: Done with Interval 87 / 95
# 	Y     = 1.492005e-04
# 	sigma = 1.907850e-04
# 	SNR   = 0.782035
# stochastic: Done with Interval 88 / 95
# 	Y     = 3.864348e-04
# 	sigma = 1.902289e-04
# 	SNR   = 2.031420
# stochastic: Done with Interval 89 / 95
# 	Y     = 1.466370e-04
# 	sigma = 1.897698e-04
# 	SNR   = 0.772710
# stochastic: Done with Interval 90 / 95
# 	Y     = 3.262527e-04
# 	sigma = 1.898985e-04
# 	SNR   = 1.718038
# stochastic: Done with Interval 91 / 95
# 	Y     = 1.852310e-04
# 	sigma = 1.897544e-04
# 	SNR   = 0.976161
# stochastic: Done with Interval 92 / 95
# 	Y     = 1.935201e-04
# 	sigma = 1.898252e-04
# 	SNR   = 1.019464
# stochastic: Done with Interval 93 / 95
# 	Y     = 1.950235e-04
# 	sigma = 1.899874e-04
# 	SNR   = 1.026508
# stochastic: Done with Interval 94 / 95
# 	Y     = 1.257606e-04
# 	sigma = 1.894711e-04
# 	SNR   = 0.663746
# stochastic: Done with Interval 95 / 95
# 	Y     = 4.057623e-04
# 	sigma = 1.895347e-04
# 	SNR   = 2.140834

# %%
# combine point estimates and error bars assuming that stochastic was run with fixed alpha
Y_opt,sig_opt = postprocessing(Ys,sigs,jobDuration,segmentDuration,deltaF,deltaT,bufferSecs=0)

print('Y_opt =', Y_opt)
print('sig_opt =', sig_opt)
# Out:
# Y_opt = 0.0002199247760049486
# sig_opt = 0.00010935204043609422

# %%
# ALTERNATIVE CALCULATION!!!
# combine spectra over times

Y_f,var_f=postprocessing_spectra(Y_fs,var_fs,jobDuration,segmentDuration,
                                 deltaFStoch,deltaT)
# Out:
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:14: RuntimeWarning: invalid value encountered in divide
#   Y_f_o = np.sum(Y_fs_odds / var_fs_odds,axis=1) / np.sum(1/var_fs_odds,axis=1)
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:15: RuntimeWarning: divide by zero encountered in divide
#   v_f_o = 1/np.sum(1/var_fs_odds,axis=1)
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:17: RuntimeWarning: invalid value encountered in divide
#   Y_f_e = np.sum(Y_fs_evens / var_fs_evens,axis=1) / np.sum(1/var_fs_evens,axis=1)
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:18: RuntimeWarning: divide by zero encountered in divide
#   v_f_e = 1/np.sum(1/var_fs_evens,axis=1)
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:28: RuntimeWarning: invalid value encountered in subtract
#   detC_f = C_f_oo*C_f_ee - C_f_oe**2
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:30: RuntimeWarning: invalid value encountered in subtract
#   lambda_f_o = (v_f_e - v_f_oe) / detC_f
# /var/folders/h9/8jj76gb51nq2gjkzk76xh3l415264w/T/ipykernel_40620/2966287306.py:31: RuntimeWarning: invalid value encountered in subtract
#   lambda_f_e = (v_f_o - v_f_oe) / detC_f

# %%
f_filter=freqs>1
y_opt,s_opt=calc_Y_sigma_from_Yf_varf(np.real(Y_f[f_filter]),
                          var_f[f_filter],
                          freqs=freqs[f_filter],
                          alpha=3,
                          fref=25)

print('y_opt =', y_opt)
print('s_opt =', s_opt)
#print('Optimal SNR [alpha=3]: %f'%(y_opt/s_opt))
# Out:
# y_opt = 0.00023474820625935702
# s_opt = 2.798999442708748e-05

# %%
# A few simple setup steps
label = 'GWB_powerlaw'
outdir = 'outdir'

cleanup_dir(outdir)

Amin,Amax,alpha_min,alpha_max=1e-10,1e-3,-5,5
    

fref=25

likelihood = BasicPowerLawGWBLikelihood(Y_f[1:],var_f[1:],freqs[1:],fref)
priors = dict(A=bilby.core.prior.Uniform(Amin,Amax, 'A'),
              alpha=bilby.core.prior.Uniform(alpha_min,alpha_max, 'alpha'))

# And run sampler
result = bilby.run_sampler(
    likelihood=likelihood, priors=priors, sampler='dynesty', npoints=500,
    walks=10, outdir=outdir, label=label,maxmcmc=50000)
result.plot_corner()
# Out:
# 19:13 bilby INFO    : Running for label 'GWB_powerlaw', output will be saved to 'outdir'
# 19:13 bilby INFO    : Analysis priors:
# 19:13 bilby INFO    : A=Uniform(minimum=1e-10, maximum=0.001, name='A', latex_label='A', unit=None, boundary=None)
# 19:13 bilby INFO    : alpha=Uniform(minimum=-5, maximum=5, name='alpha', latex_label='alpha', unit=None, boundary=None)
# 19:13 bilby INFO    : Analysis likelihood class: <class '__main__.BasicPowerLawGWBLikelihood'>
# 19:13 bilby INFO    : Analysis likelihood noise evidence: -1557.6061326635227
# 19:13 bilby INFO    : Single likelihood evaluation took 4.623e-05 s
# 19:13 bilby INFO    : Using sampler Dynesty with kwargs {'nlive': 500, 'bound': 'live', 'sample': 'act-walk', 'periodic': None, 'reflective': None, 'update_interval': 600, 'first_update': None, 'npdim': None, 'rstate': None, 'queue_size': 1, 'pool': None, 'use_pool': None, 'live_points': None, 'logl_args': None, 'logl_kwargs': None, 'ptform_args': None, 'ptform_kwargs': None, 'gradient': None, 'grad_args': None, 'grad_kwargs': None, 'compute_jac': False, 'enlarge': None, 'bootstrap': None, 'walks': 10, 'facc': 0.2, 'slices': None, 'fmove': 0.9, 'max_move': 100, 'update_func': None, 'ncdim': None, 'blob': False, 'save_history': False, 'history_filename': None, 'maxiter': None, 'maxcall': None, 'dlogz': 0.1, 'logl_max': inf, 'n_effective': None, 'add_live': True, 'print_progress': True, 'print_func': <bound method Dynesty._print_func of <bilby.core.sampler.dynesty.Dynesty object at 0x16fa27890>>, 'save_bounds': False, 'checkpoint_file': None, 'checkpoint_every': 60, 'resume': False, 'seed': None}
# 19:13 bilby INFO    : Global meta data was removed from the result object for compatibility. Use the `BILBY_INCLUDE_GLOBAL_METADATA` environment variable to include it. This behaviour will be removed in a future release. For more details see: https://bilby-dev.github.io/bilby/faq.html#global-meta-data
# 19:13 bilby INFO    : Checkpoint every check_point_delta_t = 600s
# 19:13 bilby INFO    : Using dynesty version 2.1.5
# 19:13 bilby INFO    : Using the bilby-implemented act-walk sampling tracking the autocorrelation function and thinning by 2 with maximum length 100000
# 19:13 bilby INFO    : Resume file outdir/GWB_powerlaw_resume.pickle does not exist.
# 19:13 bilby INFO    : Generating initial points from the prior
# 4305it [00:04, 690.00it/s, bound:97 nc: 20 ncall:7.7e+04 eff:5.6% logz-ratio=29.22+/-nan dlogz:0.111>0.1]
# 19:13 bilby INFO    : Written checkpoint file outdir/GWB_powerlaw_resume.pickle
# 4354it [00:06, 672.85it/s, bound:98 nc:  1 ncall:7.8e+04 eff:6.2% logz-ratio=29.33+/-0.10 dlogz:0.000>0.1]
# 19:13 bilby INFO    : Rejection sampling nested samples to obtain 1303 posterior samples
# 19:13 bilby INFO    : Sampling time: 0:00:06.469387
# 19:13 bilby INFO    : Summary of results:
# nsamples: 1303
# ln_noise_evidence: -1557.606
# ln_evidence: -1528.280 +/-  0.130
# ln_bayes_factor: 29.326 +/-  0.130

# %%
A=result.samples[:,0]
alpha=result.samples[:,1]

# %%
plt.hist(A,bins=30,histtype='step',color='blue')
plt.axvline(np.percentile(A,5),color='blue',linestyle='--')
plt.axvline(np.percentile(A,95),color='blue',linestyle='--')

plt.axvline(Y_theor,color='red', label='injected')


plt.axvline(y_opt,color='grey', linewidth=3, label='point estimate')
plt.axvline(y_opt+s_opt,color='grey', linestyle='--')
plt.axvline(y_opt-s_opt,color='grey', linestyle='--')

plt.axvline(Y_opt,color='magenta', linestyle='-', label='point estimate')
plt.axvline(Y_opt+sig_opt,color='magenta', linestyle='--')
plt.axvline(Y_opt-sig_opt,color='magenta', linestyle='--')

plt.legend()

plt.title('A')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
plt.hist(alpha,bins=30,histtype='step',color='blue')
plt.axvline(np.percentile(alpha,5),color='blue',linestyle='--')
plt.axvline(np.percentile(alpha,95),color='blue',linestyle='--')

plt.axvline(3,color='red')

plt.title('alpha')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')
